# %% [markdown]
# ## Create study area plot

# %%
"""
Study area map — single panel, jerarquia=0 main basins
colored by glaciological cluster, per Alexis Caro feedback
"""

import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# ── Paths ──────────────────────────────────────────────────────────────────
BASE        = '/Users/milliespencer/Desktop/CR2_OGGM_Paper'
FILTRADO    = f'{BASE}/Camels_filtrado'
RGI_PATH    = (f'{BASE}/files_chile_OGGM_climate_comparison/'
               f'RGI_BNA_Clusters.csv')
BOUNDS_PATH = (f'{BASE}/Full_CAMELS_all_basins/CAMELS_CL_v202201/'
               f'camels_cl_boundaries/camels_cl_boundaries.shp')

# ── Cluster colors and labels ──────────────────────────────────────────────
cluster_colors = {
    'OT3': '#e6194b', 'DA1': '#f58231', 'DA2': '#ffe119',
    'DA3': '#bfef45', 'WA1': '#3cb44b', 'WA2': '#42d4f4',
    'WA3': '#4363d8', 'WA4': '#911eb4', 'WA5': '#f032e6',
    'WA6': '#01665e',  # changed from grey to dark teal
}
cluster_labels = {
    'OT3': 'Altiplano',    'DA1': 'Dry Andes N',
    'DA2': 'Dry Andes C',  'DA3': 'Dry Andes S',
    'WA1': 'Wet Andes N',  'WA2': 'Wet Andes C',
    'WA3': 'N Patagonia',  'WA4': 'S Patagonia',
    'WA5': 'Patagonia',    'WA6': 'Tierra del Fuego',
}
CLUSTERS = ['OT3','DA1','DA2','DA3','WA1','WA2',
            'WA3','WA4','WA5','WA6']

# ── Glacier area per cluster from RGI ─────────────────────────────────────
rgi = pd.read_csv(RGI_PATH)
cluster_stats = (rgi.groupby('Cluster')
                 .agg(n_glaciers=('RGIId', 'count'),
                      area_km2  =('Area',  'sum'))
                 .reset_index())

# ── Load jerarquia=0 main basins ──────────────────────────────────────────
hier = gpd.read_file(f'{FILTRADO}/Camels_jerarquia.shp')
hier['gauge_id'] = hier['gauge_id'].astype(str)
main_basins = hier[hier['jerarquia'] == 0].copy()

if main_basins.crs and main_basins.crs.to_epsg() != 4326:
    main_basins = main_basins.to_crs(epsg=4326)

# Assign cluster from GAUGE_INFO_FRAC
gauge_to_cluster = {
    str(gid): info['clusters'][0]
    for gid, info in GAUGE_INFO_FRAC.items()
}
main_basins['cluster'] = main_basins['gauge_id'].map(gauge_to_cluster)

print(f'Main basins (jerarquia=0): {len(main_basins)}')
print(f'With cluster assignment:   '
      f'{main_basins["cluster"].notna().sum()}')

# ── Load all CAMELS boundaries for grey background ────────────────────────
bounds = gpd.read_file(BOUNDS_PATH)
bounds['gauge_id'] = bounds['gauge_id'].astype(str)

# ── Country borders ────────────────────────────────────────────────────────
try:
    world = gpd.read_file(
        'https://naturalearth.s3.amazonaws.com/50m_cultural/'
        'ne_50m_admin_0_countries.zip')
    chile       = world[world['NAME'] == 'Chile']
    arg         = world[world['NAME'] == 'Argentina']
    has_borders = True
except Exception:
    has_borders = False
    print('Country borders unavailable — plotting without')

# ── Figure: single panel ───────────────────────────────────────────────────
fig = plt.figure(figsize=(8, 20))
ax  = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([-77, -65, -56, -17], crs=ccrs.PlateCarree())

# Ocean
ax.add_feature(cfeature.OCEAN, facecolor='#d6e8f5', zorder=0)

# Base land
ax.add_feature(cfeature.LAND, facecolor='#f0f0f0',
               edgecolor='none', zorder=0)

# Argentina
if has_borders:
    arg.plot(ax=ax, facecolor='#ebebeb', edgecolor='#555555',
             linewidth=0.8, zorder=1,
             transform=ccrs.PlateCarree())

# All CAMELS boundaries — light grey background
bounds.plot(ax=ax, facecolor='#d8d8d8', edgecolor='#bbbbbb',
            linewidth=0.15, zorder=2)

# Main basins colored by cluster
for cl in CLUSTERS:
    cl_basins = main_basins[main_basins['cluster'] == cl]
    if len(cl_basins) == 0:
        continue
    cl_basins.plot(ax=ax,
                   facecolor=cluster_colors[cl],
                   edgecolor='k',
                   linewidth=0.4,
                   alpha=0.85,
                   zorder=3)

# Unassigned main basins in grey
unassigned = main_basins[main_basins['cluster'].isna()]
if len(unassigned):
    unassigned.plot(ax=ax, facecolor='#cccccc',
                    edgecolor='#888888', linewidth=0.3,
                    alpha=0.6, zorder=3)

# Coastline on top
ax.add_feature(cfeature.COASTLINE, linewidth=0.8,
               edgecolor='#333333', zorder=4)

# Gridlines
gl = ax.gridlines(draw_labels=True, linewidth=0.4,
                  alpha=0.4, linestyle='--')
gl.top_labels   = False
gl.right_labels = False
gl.xlabel_style = {'size': 8}
gl.ylabel_style = {'size': 8}

ax.set_title('Glacierized basins by glaciological cluster\n'
             'Main basins (jerarquia=0) only',
             fontsize=11, fontweight='bold', pad=8)

# ── Legend: upper right, cluster + n glaciers + glacier area ──────────────
legend_handles = []
for cl in CLUSTERS:
    stats = cluster_stats[cluster_stats['Cluster'] == cl]
    if len(stats) == 0:
        n, area = 0, 0.0
    else:
        n    = int(stats['n_glaciers'].values[0])
        area = float(stats['area_km2'].values[0])
    label = (f'{cl}  {cluster_labels[cl]}\n'
             f'     {n:,} glaciers  |  {area:,.0f} km²')
    legend_handles.append(mpatches.Patch(
        facecolor=cluster_colors[cl],
        edgecolor='k', linewidth=0.5,
        label=label))

legend_handles.append(mpatches.Patch(
    facecolor='#d8d8d8', edgecolor='#bbbbbb',
    linewidth=0.3, label='Other gauged basins\n(not in analysis)'))

ax.legend(handles=legend_handles,
          loc='upper left',           
          fontsize=7,
          framealpha=0.93,
          title='Glaciological cluster\n(n glaciers | glacier area)',
          title_fontsize=7.5,
          bbox_to_anchor=(0.01, 0.99))

# ── Save ──────────────────────────────────────────────────────────────────
out_path = f'{BASE}/Output/study_area_map_single_panel.png'
plt.tight_layout()
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved: {out_path}')
# Out:
# Main basins (jerarquia=0): 146
# With cluster assignment:   41
# Saved: /Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/study_area_map_single_panel.png

# %% [markdown]
# Model run comparison for DA1

# %%
"""
Study area map - WA3 cluster only
"""

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Load RGI data
datos_rgi = pd.read_csv(
    '/Users/milliespencer/Desktop/CR2_OGGM_Paper/'
    'files_chile_OGGM_climate_comparison/RGI_BNA_Clusters.csv')

gdf = gpd.GeoDataFrame(
    datos_rgi,
    geometry=gpd.points_from_xy(datos_rgi.CenLon, datos_rgi.CenLat),
    crs='EPSG:4326')

# WA3 only
wa3 = gdf[gdf['Cluster'] == 'WA3']
print(f'WA3 glaciers: {len(wa3)}')
print(f'Lon range: {wa3.CenLon.min():.2f} to {wa3.CenLon.max():.2f}')
print(f'Lat range: {wa3.CenLat.min():.2f} to {wa3.CenLat.max():.2f}')

# ── Figure: two panels ────────────────────────────────────────────────────
fig = plt.figure(figsize=(12, 10))

# ── Panel 1: South America context ────────────────────────────────────────
ax1 = fig.add_subplot(1, 2, 1, projection=ccrs.PlateCarree())
ax1.set_extent([-85, -30, -60, 15], crs=ccrs.PlateCarree())
ax1.add_feature(cfeature.LAND,      facecolor='lightgray', edgecolor='none')
ax1.add_feature(cfeature.OCEAN,     facecolor='lightblue')
ax1.add_feature(cfeature.COASTLINE, linewidth=0.5)
ax1.add_feature(cfeature.BORDERS,   linewidth=0.5, alpha=0.5)

# All glaciers as background
ax1.scatter(gdf.CenLon, gdf.CenLat,
            s=1, c='lightgray', alpha=0.3,
            transform=ccrs.PlateCarree())

# WA3 highlighted
ax1.scatter(wa3.CenLon, wa3.CenLat,
            s=8, c='#a65628', alpha=0.8,
            transform=ccrs.PlateCarree(),
            label=f'WA3 (n={len(wa3)})')

# Bounding box around WA3
lon_pad, lat_pad = 1.5, 0.5
from matplotlib.patches import Rectangle
ax1.add_patch(Rectangle(
    xy=(wa3.CenLon.min() - lon_pad, wa3.CenLat.min() - lat_pad),
    width=(wa3.CenLon.max() - wa3.CenLon.min()) + 2 * lon_pad,
    height=(wa3.CenLat.max() - wa3.CenLat.min()) + 2 * lat_pad,
    facecolor='none', edgecolor='#a65628',
    linewidth=2, transform=ccrs.PlateCarree()))

ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5)
ax1.set_title('Study Area Context\nWA3 highlighted', 
              fontsize=13, fontweight='bold')
ax1.legend(loc='lower left', fontsize=9, framealpha=0.9)

# ── Panel 2: WA3 detail ───────────────────────────────────────────────────
lon_min = wa3.CenLon.min() - lon_pad
lon_max = wa3.CenLon.max() + lon_pad
lat_min = wa3.CenLat.min() - lat_pad
lat_max = wa3.CenLat.max() + lat_pad

ax2 = fig.add_subplot(1, 2, 2, projection=ccrs.PlateCarree())
ax2.set_extent([lon_min, lon_max, lat_min, lat_max],
               crs=ccrs.PlateCarree())

ax2.add_feature(cfeature.LAND,      facecolor='#f5f5f0', edgecolor='black', linewidth=1)
ax2.add_feature(cfeature.OCEAN,     facecolor='#d0e8f0')
ax2.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor='black')
ax2.add_feature(cfeature.BORDERS,   linewidth=0.8, alpha=0.6)
ax2.add_feature(cfeature.RIVERS,    linewidth=0.5, edgecolor='steelblue', alpha=0.5)

ax2.scatter(wa3.CenLon, wa3.CenLat,
            s=25, c='#a65628', alpha=0.8,
            transform=ccrs.PlateCarree(),
            edgecolors='black', linewidths=0.3,
            label=f'WA3 (n={len(wa3)})',
            zorder=5)

gl = ax2.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5)
gl.top_labels   = False
gl.right_labels = False
ax2.set_title('WA3 Cluster Detail', fontsize=13, fontweight='bold')
ax2.legend(loc='upper left', fontsize=9, framealpha=0.9)

# Cluster stats as text box
area_total = wa3['Area'].sum() if 'Area' in wa3.columns else \
             wa3['Area_km2'].sum() if 'Area_km2' in wa3.columns else None
stats_text = f'N glaciers: {len(wa3)}'
if area_total is not None:
    stats_text += f'\nTotal area: {area_total:.1f} km²'
stats_text += f'\nLat: {wa3.CenLat.min():.1f}° to {wa3.CenLat.max():.1f}°S'

ax2.text(0.02, 0.02, stats_text,
         transform=ax2.transAxes,
         fontsize=9, verticalalignment='bottom',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.suptitle('WA3 Glacier Cluster — Greatest Glacier Loss (MB rate)',
             fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(
    '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Study_Area_Map_WA3.png',
    dpi=300, bbox_inches='tight')
plt.show()
print(f'Saved: Study_Area_Map_WA3.png')
# Out:
# WA3 glaciers: 447
# Lon range: -73.92 to -72.85
# Lat range: -51.34 to -46.34
# Saved: Study_Area_Map_WA3.png

# %%
"""
Study area map - WA1 cluster only
"""

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.patches import Rectangle

# Load RGI data
datos_rgi = pd.read_csv(
    '/Users/milliespencer/Desktop/CR2_OGGM_Paper/'
    'files_chile_OGGM_climate_comparison/RGI_BNA_Clusters.csv')

gdf = gpd.GeoDataFrame(
    datos_rgi,
    geometry=gpd.points_from_xy(datos_rgi.CenLon, datos_rgi.CenLat),
    crs='EPSG:4326')

# WA1 only
wa1 = gdf[gdf['Cluster'] == 'WA1']
print(f'WA1 glaciers: {len(wa1)}')
print(f'Lon range: {wa1.CenLon.min():.2f} to {wa1.CenLon.max():.2f}')
print(f'Lat range: {wa1.CenLat.min():.2f} to {wa1.CenLat.max():.2f}')

# ── Figure: two panels ────────────────────────────────────────────────────
fig = plt.figure(figsize=(12, 10))

# ── Panel 1: South America context ────────────────────────────────────────
ax1 = fig.add_subplot(1, 2, 1, projection=ccrs.PlateCarree())
ax1.set_extent([-85, -30, -60, 15], crs=ccrs.PlateCarree())
ax1.add_feature(cfeature.LAND,      facecolor='lightgray', edgecolor='none')
ax1.add_feature(cfeature.OCEAN,     facecolor='lightblue')
ax1.add_feature(cfeature.COASTLINE, linewidth=0.5)
ax1.add_feature(cfeature.BORDERS,   linewidth=0.5, alpha=0.5)

# All glaciers as background
ax1.scatter(gdf.CenLon, gdf.CenLat,
            s=1, c='lightgray', alpha=0.3,
            transform=ccrs.PlateCarree())

# WA1 highlighted
ax1.scatter(wa1.CenLon, wa1.CenLat,
            s=8, c='#ff7f00', alpha=0.8,
            transform=ccrs.PlateCarree(),
            label=f'WA1 (n={len(wa1)})')

# Bounding box around WA1
lon_pad, lat_pad = 1.5, 0.5
ax1.add_patch(Rectangle(
    xy=(wa1.CenLon.min() - lon_pad, wa1.CenLat.min() - lat_pad),
    width=(wa1.CenLon.max() - wa1.CenLon.min()) + 2 * lon_pad,
    height=(wa1.CenLat.max() - wa1.CenLat.min()) + 2 * lat_pad,
    facecolor='none', edgecolor='#ff7f00',
    linewidth=2, transform=ccrs.PlateCarree()))

ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5)
ax1.set_title('Study Area Context\nWA1 highlighted',
              fontsize=13, fontweight='bold')
ax1.legend(loc='lower left', fontsize=9, framealpha=0.9)

# ── Panel 2: WA1 detail ───────────────────────────────────────────────────
lon_min = wa1.CenLon.min() - lon_pad
lon_max = wa1.CenLon.max() + lon_pad
lat_min = wa1.CenLat.min() - lat_pad
lat_max = wa1.CenLat.max() + lat_pad

ax2 = fig.add_subplot(1, 2, 2, projection=ccrs.PlateCarree())
ax2.set_extent([lon_min, lon_max, lat_min, lat_max],
               crs=ccrs.PlateCarree())

ax2.add_feature(cfeature.LAND,      facecolor='#f5f5f0', edgecolor='black', linewidth=1)
ax2.add_feature(cfeature.OCEAN,     facecolor='#d0e8f0')
ax2.add_feature(cfeature.COASTLINE, linewidth=1, edgecolor='black')
ax2.add_feature(cfeature.BORDERS,   linewidth=0.8, alpha=0.6)
ax2.add_feature(cfeature.RIVERS,    linewidth=0.5, edgecolor='steelblue', alpha=0.5)

ax2.scatter(wa1.CenLon, wa1.CenLat,
            s=25, c='#ff7f00', alpha=0.8,
            transform=ccrs.PlateCarree(),
            edgecolors='black', linewidths=0.3,
            label=f'WA1 (n={len(wa1)})',
            zorder=5)

gl = ax2.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5)
gl.top_labels   = False
gl.right_labels = False
ax2.set_title('WA1 Cluster Detail', fontsize=13, fontweight='bold')
ax2.legend(loc='upper left', fontsize=9, framealpha=0.9)

# Stats text box
area_total = wa1['Area'].sum() if 'Area' in wa1.columns else \
             wa1['Area_km2'].sum() if 'Area_km2' in wa1.columns else None
stats_text = f'N glaciers: {len(wa1)}'
if area_total is not None:
    stats_text += f'\nTotal area: {area_total:.1f} km²'
stats_text += f'\nLat: {wa1.CenLat.min():.1f}° to {wa1.CenLat.max():.1f}°S'

ax2.text(0.02, 0.02, stats_text,
         transform=ax2.transAxes,
         fontsize=9, verticalalignment='bottom',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.suptitle('WA1 Glacier Cluster — Chilean Wet Andes',
             fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(
    '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Study_Area_Map_WA1.png',
    dpi=300, bbox_inches='tight')
plt.show()
print('Saved: Study_Area_Map_WA1.png')
# Out:
# WA1 glaciers: 678
# Lon range: -72.05 to -70.50
# Lat range: -40.23 to -35.51
# Saved: Study_Area_Map_WA1.png

# %% [markdown]
# ## Plots for Ale talk

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
==============================================================================
MULTI-DATASET TIMESERIES COMPARISON - DA1 CLUSTER
==============================================================================
This script creates temporal analysis plots comparing CR2MET, ERA5, and CRU
climate datasets to see how they differ over time (2000-2019).

Author: Millie 
Date: January 2026
Dataset: DA1 Cluster (Chilean Andes)
==============================================================================
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import seaborn as sns
from datetime import datetime

# Set plotting style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Define output directory
output_dir = '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/'

# %%
##############################################################################
# SECTION 1: LOAD GEODETIC OBSERVATIONS FOR REFERENCE
##############################################################################
print("\n" + "="*70)
print("LOADING DATA...")
print("="*70)

# Load geodetic mass balance (GMB) - our "ground truth" observations
# This comes from Hugonnet et al. (2021) satellite observations
gmb_file = output_dir + 'CR2MET/DA1/comparacion_gmb_smb_DA1_.csv'
gmb_data = pd.read_csv(gmb_file, header=None)
gmb_value = float(gmb_data[gmb_data[1] == 'GMB'][0].values[0])
gmb_error = float(gmb_data[gmb_data[1] == 'GMB_error'][0].values[0])

print(f"Geodetic observations (2000-2019): {gmb_value:.1f} ± {gmb_error:.1f} mm/yr")

##############################################################################
# SECTION 2: LOAD ANNUAL MASS BALANCE TIMESERIES
##############################################################################
print("\nLoading annual mass balance timeseries...")

# Load area-weighted mean mass balance for each year
# These are the cluster-wide averages calculated in Script 02
cr2_mb_ts = pd.read_csv(output_dir + 'CR2MET/DA1/mb_promedio.csv')
era5_mb_ts = pd.read_csv(output_dir + 'ERA5/DA1/mb_promedio.csv')
cru_mb_ts = pd.read_csv(output_dir + 'CRU/DA1/mb_promedio.csv')

print(f"  CR2MET: {len(cr2_mb_ts)} years")
print(f"  ERA5:   {len(era5_mb_ts)} years")
print(f"  CRU:    {len(cru_mb_ts)} years")

##############################################################################
# SECTION 3: LOAD COMPILED NETCDF FILES WITH FULL GLACIER EVOLUTION
##############################################################################
print("\nLoading compiled NetCDF outputs (volume, area, length)...")

# These NetCDF files contain annual timeseries of glacier geometry changes
# for all glaciers in the cluster, compiled from OGGM simulations
cr2_nc = xr.open_dataset(output_dir + 'CR2MET/DA1/run_output_2000_2019_hydro_TC_DA1.nc')
era5_nc = xr.open_dataset(output_dir + 'ERA5/DA1/run_output_2000_2019_hydro_ERA5_DA1.nc')
cru_nc = xr.open_dataset(output_dir + 'CRU/DA1/run_output_2000_2019_hydro_CRU_DA1.nc')

print("  Variables available in NetCDF files:")
print(f"    {list(cr2_nc.data_vars)}")

##############################################################################
# SECTION 4: EXTRACT CLUSTER-WIDE TOTALS FOR VOLUME AND AREA
##############################################################################
print("\nCalculating cluster-wide totals...")

def calculate_cluster_totals(nc_dataset):
    """
    Calculate total volume and area across all glaciers in the cluster.
    
    Parameters:
    -----------
    nc_dataset : xarray.Dataset
        OGGM compiled output with variables: volume, area, etc.
    
    Returns:
    --------
    pandas.DataFrame with columns: year, volume_km3, area_km2
    """
    # Sum across all glaciers (axis=0 is the glacier dimension)
    total_volume = nc_dataset['volume'].sum(dim='rgi_id') / 1e9  # Convert m³ to km³
    total_area = nc_dataset['area'].sum(dim='rgi_id') / 1e6     # Convert m² to km²
    
    # Get years from time dimension
    years = nc_dataset['time'].values
    
    # Create DataFrame
    df = pd.DataFrame({
        'year': years,
        'volume_km3': total_volume.values,
        'area_km2': total_area.values
    })
    
    return df

# Calculate totals for each dataset
cr2_totals = calculate_cluster_totals(cr2_nc)
era5_totals = calculate_cluster_totals(era5_nc)
cru_totals = calculate_cluster_totals(cru_nc)

print(f"  Initial volume (2000): CR2MET={cr2_totals.iloc[0]['volume_km3']:.2f} km³")
print(f"  Final volume (2019):   CR2MET={cr2_totals.iloc[-1]['volume_km3']:.2f} km³")
print(f"  Volume loss:           {cr2_totals.iloc[0]['volume_km3'] - cr2_totals.iloc[-1]['volume_km3']:.2f} km³")

##############################################################################
# SECTION 5: EXTRACT MONTHLY HYDROLOGY DATA
##############################################################################
print("\nExtracting monthly hydrology (melt, precipitation, runoff)...")

def extract_monthly_hydrology(nc_dataset):
    """
    Extract monthly hydrological fluxes summed across all glaciers.
    
    Parameters:
    -----------
    nc_dataset : xarray.Dataset
        OGGM compiled output with monthly_* variables
    
    Returns:
    --------
    pandas.DataFrame with monthly timeseries of melt, precip, runoff
    """
    # Check what monthly variables are available
    monthly_vars = [v for v in nc_dataset.data_vars if 'month_2d' in str(nc_dataset[v].dims)]
    
    if not monthly_vars:
        print("    Warning: No monthly variables found in dataset")
        return None
    
    # Extract and sum monthly fluxes across all glaciers
    # Variables are typically: melt_off_glacier, melt_on_glacier, 
    # liq_prcp_off_glacier, liq_prcp_on_glacier, snowfall_*, etc.
    
    # Total glacier melt (on glacier surface)
    if 'melt_on_glacier' in nc_dataset:
        melt = nc_dataset['melt_on_glacier'].sum(dim='rgi_id')
    else:
        print("    Warning: melt_on_glacier not found")
        melt = None
    
    # Liquid precipitation on glacier
    if 'liq_prcp_on_glacier' in nc_dataset:
        rain = nc_dataset['liq_prcp_on_glacier'].sum(dim='rgi_id')
    else:
        print("    Warning: liq_prcp_on_glacier not found")
        rain = None
    
    # Snowfall on glacier
    if 'snowfall_on_glacier' in nc_dataset:
        snow = nc_dataset['snowfall_on_glacier'].sum(dim='rgi_id')
    else:
        snow = None
    
    # Create time index from year and month
    years = nc_dataset['time'].values
    
    # Build DataFrame
    monthly_data = []
    for i, year in enumerate(years):
        for month in range(12):
            date = pd.Timestamp(year=int(year), month=month+1, day=15)
            row = {'date': date, 'year': int(year), 'month': month+1}
            
            if melt is not None:
                row['melt_kg'] = float(melt.isel(time=i, month_2d=month).values)
            if rain is not None:
                row['rain_kg'] = float(rain.isel(time=i, month_2d=month).values)
            if snow is not None:
                row['snow_kg'] = float(snow.isel(time=i, month_2d=month).values)
            
            monthly_data.append(row)
    
    df = pd.DataFrame(monthly_data)
    
    # Calculate total runoff (melt + rain)
    if 'melt_kg' in df.columns and 'rain_kg' in df.columns:
        df['runoff_kg'] = df['melt_kg'] + df['rain_kg']
    
    return df

# Extract monthly data for each dataset
cr2_monthly = extract_monthly_hydrology(cr2_nc)
era5_monthly = extract_monthly_hydrology(era5_nc)
cru_monthly = extract_monthly_hydrology(cru_nc)

if cr2_monthly is not None:
    print(f"  Monthly data extracted: {len(cr2_monthly)} months")
    print(f"  Available columns: {list(cr2_monthly.columns)}")

##############################################################################
# SECTION 6: CALCULATE PERIOD MEANS FOR EACH DATASET
##############################################################################
print("\nCalculating period means (2000-2019)...")

# Mass balance period means
cr2_mb_mean = cr2_mb_ts['mb_mean'].mean()
era5_mb_mean = era5_mb_ts['mb_mean'].mean()
cru_mb_mean = cru_mb_ts['mb_mean'].mean()

print(f"  CR2MET mean MB:  {cr2_mb_mean:.3f} m w.e./yr")
print(f"  ERA5 mean MB:    {era5_mb_mean:.3f} m w.e./yr")
print(f"  CRU mean MB:     {cru_mb_mean:.3f} m w.e./yr")

# Volume change rates (km³/yr)
cr2_vol_change = (cr2_totals.iloc[-1]['volume_km3'] - cr2_totals.iloc[0]['volume_km3']) / len(cr2_totals)
era5_vol_change = (era5_totals.iloc[-1]['volume_km3'] - era5_totals.iloc[0]['volume_km3']) / len(era5_totals)
cru_vol_change = (cru_totals.iloc[-1]['volume_km3'] - cru_totals.iloc[0]['volume_km3']) / len(cru_totals)

print(f"  CR2MET volume change:  {cr2_vol_change:.4f} km³/yr")
print(f"  ERA5 volume change:    {era5_vol_change:.4f} km³/yr")
print(f"  CRU volume change:     {cru_vol_change:.4f} km³/yr")
# Out:
# ======================================================================
# LOADING DATA...
# ======================================================================
# Geodetic observations (2000-2019): -98.7 ± 152.6 mm/yr
#
# Loading annual mass balance timeseries...
#   CR2MET: 22 years
#   ERA5:   20 years
#   CRU:    20 years
#
# Loading compiled NetCDF outputs (volume, area, length)...
#   Variables available in NetCDF files:
#     ['volume', 'volume_bsl', 'volume_bwl', 'area', 'length', 'calving', 'calving_rate', 'off_area', 'on_area', 'melt_off_glacier', 'melt_on_glacier', 'liq_prcp_off_glacier', 'liq_prcp_on_glacier', 'snowfall_off_glacier', 'snowfall_on_glacier', 'melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly', 'water_level', 'glen_a', 'fs']
#
# Calculating cluster-wide totals...
#   Initial volume (2000): CR2MET=5.60 km³
#   Final volume (2019):   CR2MET=5.25 km³
#   Volume loss:           0.35 km³
#
# Extracting monthly hydrology (melt, precipitation, runoff)...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 166
#     163     return df
#     165 # Extract monthly data for each dataset
# --> 166 cr2_monthly = extract_monthly_hydrology(cr2_nc)
#     167 era5_monthly = extract_monthly_hydrology(era5_nc)
#     168 cru_monthly = extract_monthly_hydrology(cru_nc)
#
# Cell In[9], line 149, in extract_monthly_hydrology(nc_dataset)
#     146 row = {'date': date, 'year': int(year), 'month': month+1}
#     148 if melt is not None:
# --> 149     row['melt_kg'] = float(melt.isel(time=i, month_2d=month).values)
#     150 if rain is not None:
#     151     row['rain_kg'] = float(rain.isel(time=i, month_2d=month).values)
#
# File ~/miniconda3/envs/oggm_cr2_env/lib/python3.11/site-packages/xarray/core/dataarray.py:1582, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1577     return self._from_temp_dataset(ds)
#    1579 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1580 # lists, or zero or one-dimensional np.ndarray's
# -> 1582 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1583 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1585 coords = {}
#
# File ~/miniconda3/envs/oggm_cr2_env/lib/python3.11/site-packages/xarray/core/variable.py:1127, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1103 """Return a new array indexed along the specified dimension(s).
#    1104
#    1105 Parameters
#    (...)   1123     indexer, in which case the data will be a copy.
#    1124 """
#    1125 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
# -> 1127 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1129 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
#    1130 return self[key]
#
# File ~/miniconda3/envs/oggm_cr2_env/lib/python3.11/site-packages/xarray/core/utils.py:938, in drop_dims_from_indexers(indexers, dims, missing_dims)
#     936     invalid = indexers.keys() - set(dims)
#     937     if invalid:
# --> 938         raise ValueError(
#     939             f"Dimensions {invalid} do not exist. Expected one or more of {dims}"
#     940         )
#     942     return indexers
#     944 elif missing_dims == "warn":
#     945     # don't modify input
#
# ValueError: Dimensions {'month_2d'} do not exist. Expected one or more of ('time',)

# %%
##############################################################################
# PLOT 1: ANNUAL MASS BALANCE TIMESERIES
##############################################################################
print("\nCreating Plot 1: Annual Mass Balance Timeseries...")

fig1, ax1 = plt.subplots(figsize=(14, 8))

# Define colors for consistency
colors = {'CR2MET': '#e74c3c', 'ERA5': '#3498db', 'CRU': '#2ecc71'}

# Plot annual mass balance timeseries for each dataset
ax1.plot(cr2_mb_ts['year'], cr2_mb_ts['mb_mean'], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax1.plot(era5_mb_ts['year'], era5_mb_ts['mb_mean'], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax1.plot(cru_mb_ts['year'], cru_mb_ts['mb_mean'], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Add period mean lines for each dataset (horizontal reference lines)
ax1.axhline(y=cr2_mb_mean, color=colors['CR2MET'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'CR2MET mean: {cr2_mb_mean:.3f} m/yr')
ax1.axhline(y=era5_mb_mean, color=colors['ERA5'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'ERA5 mean: {era5_mb_mean:.3f} m/yr')
ax1.axhline(y=cru_mb_mean, color=colors['CRU'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'CRU mean: {cru_mb_mean:.3f} m/yr')

# Add geodetic observation reference (converted to m/yr)
ax1.axhline(y=gmb_value/1000, color='darkred', linestyle=':', 
           linewidth=3, label=f'Geodetic Obs: {gmb_value/1000:.3f} m/yr', alpha=0.7)
ax1.axhspan((gmb_value - gmb_error)/1000, (gmb_value + gmb_error)/1000, 
           alpha=0.1, color='gray', label='GMB uncertainty')

# Formatting
ax1.set_xlabel('Year', fontsize=14, fontweight='bold')
ax1.set_ylabel('Mass Balance (m w.e./yr)', fontsize=14, fontweight='bold')
ax1.set_title('Annual Mass Balance Timeseries - DA1 Cluster\n' + 
             'Comparison of CR2MET, ERA5, and CRU Climate Forcing',
             fontsize=16, fontweight='bold', pad=20)
ax1.legend(loc='best', fontsize=11, framealpha=0.95)
ax1.grid(True, alpha=0.4, linestyle='--')
ax1.axhline(y=0, color='black', linewidth=1)

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_01_Mass_Balance_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_01_Mass_Balance_DA1.png")

# %%
##############################################################################
# PLOT 2: GLACIER VOLUME EVOLUTION
##############################################################################
print("\nCreating Plot 2: Volume Evolution...")

fig2, ax2 = plt.subplots(figsize=(14, 8))

# Plot total glacier volume over time
ax2.plot(cr2_totals['year'], cr2_totals['volume_km3'], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax2.plot(era5_totals['year'], era5_totals['volume_km3'], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax2.plot(cru_totals['year'], cru_totals['volume_km3'], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Add trend lines (linear fit)
from scipy.stats import linregress

for name, totals, color in [('CR2MET', cr2_totals, colors['CR2MET']),
                              ('ERA5', era5_totals, colors['ERA5']),
                              ('CRU', cru_totals, colors['CRU'])]:
    slope, intercept, r_value, p_value, std_err = linregress(totals['year'], totals['volume_km3'])
    trend_line = slope * totals['year'] + intercept
    ax2.plot(totals['year'], trend_line, '--', color=color, linewidth=1.5, 
            alpha=0.5, label=f'{name} trend: {slope:.4f} km³/yr')

# Formatting
ax2.set_xlabel('Year', fontsize=14, fontweight='bold')
ax2.set_ylabel('Total Glacier Volume (km³)', fontsize=14, fontweight='bold')
ax2.set_title('Glacier Volume Evolution - DA1 Cluster\n' + 
             'Total volume change under different climate forcings',
             fontsize=16, fontweight='bold', pad=20)
ax2.legend(loc='best', fontsize=11, framealpha=0.95)
ax2.grid(True, alpha=0.4, linestyle='--')

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_02_Volume_Evolution_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_02_Volume_Evolution_DA1.png")

# %%
##############################################################################
# PLOT 3: GLACIER AREA EVOLUTION
##############################################################################
print("\nCreating Plot 3: Area Evolution...")

fig3, ax3 = plt.subplots(figsize=(14, 8))

# Plot total glacier area over time
ax3.plot(cr2_totals['year'], cr2_totals['area_km2'], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax3.plot(era5_totals['year'], era5_totals['area_km2'], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax3.plot(cru_totals['year'], cru_totals['area_km2'], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Calculate percent change
cr2_area_pct = ((cr2_totals.iloc[-1]['area_km2'] - cr2_totals.iloc[0]['area_km2']) / 
                cr2_totals.iloc[0]['area_km2'] * 100)
era5_area_pct = ((era5_totals.iloc[-1]['area_km2'] - era5_totals.iloc[0]['area_km2']) / 
                 era5_totals.iloc[0]['area_km2'] * 100)
cru_area_pct = ((cru_totals.iloc[-1]['area_km2'] - cru_totals.iloc[0]['area_km2']) / 
                cru_totals.iloc[0]['area_km2'] * 100)

# Formatting
ax3.set_xlabel('Year', fontsize=14, fontweight='bold')
ax3.set_ylabel('Total Glacier Area (km²)', fontsize=14, fontweight='bold')
ax3.set_title('Glacier Area Evolution - DA1 Cluster\n' + 
             f'CR2MET: {cr2_area_pct:.1f}% | ERA5: {era5_area_pct:.1f}% | CRU: {cru_area_pct:.1f}% change',
             fontsize=16, fontweight='bold', pad=20)
ax3.legend(loc='best', fontsize=11, framealpha=0.95)
ax3.grid(True, alpha=0.4, linestyle='--')

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_03_Area_Evolution_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_03_Area_Evolution_DA1.png")

# %%
##############################################################################
# PLOT 4: MONTHLY HYDROLOGY - TOTAL RUNOFF
##############################################################################
print("\nCreating Plot 4: Monthly Runoff Timeseries...")

if cr2_monthly is not None and 'runoff_kg' in cr2_monthly.columns:
    fig4, ax4 = plt.subplots(figsize=(16, 8))
    
    # Convert kg to Gt (gigatonnes) for better readability: 1 Gt = 1e12 kg
    cr2_monthly['runoff_Gt'] = cr2_monthly['runoff_kg'] / 1e12
    era5_monthly['runoff_Gt'] = era5_monthly['runoff_kg'] / 1e12
    cru_monthly['runoff_Gt'] = cru_monthly['runoff_kg'] / 1e12
    
    # Plot monthly runoff
    ax4.plot(cr2_monthly['date'], cr2_monthly['runoff_Gt'], '-', 
             color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax4.plot(era5_monthly['date'], era5_monthly['runoff_Gt'], '-', 
             color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax4.plot(cru_monthly['date'], cru_monthly['runoff_Gt'], '-', 
             color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    # Formatting
    ax4.set_xlabel('Date', fontsize=14, fontweight='bold')
    ax4.set_ylabel('Total Runoff (Gt/month)', fontsize=14, fontweight='bold')
    ax4.set_title('Monthly Glacier Runoff - DA1 Cluster\n' + 
                 'Total runoff = glacier melt + rainfall on glacier',
                 fontsize=16, fontweight='bold', pad=20)
    ax4.legend(loc='best', fontsize=11, framealpha=0.95)
    ax4.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_04_Monthly_Runoff_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_04_Monthly_Runoff_DA1.png")
else:
    print("  ⚠ Warning: Monthly runoff data not available - skipping Plot 4")

# %%
##############################################################################
# PLOT 5: MONTHLY COMPONENTS - MELT VS RAIN
##############################################################################
print("\nCreating Plot 5: Melt vs Rain Comparison...")

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    fig5, (ax5a, ax5b) = plt.subplots(2, 1, figsize=(16, 12))
    
    # Convert to Gt
    for df in [cr2_monthly, era5_monthly, cru_monthly]:
        df['melt_Gt'] = df['melt_kg'] / 1e12
        df['rain_Gt'] = df['rain_kg'] / 1e12
    
    # TOP PANEL: Glacier Melt
    ax5a.plot(cr2_monthly['date'], cr2_monthly['melt_Gt'], '-', 
              color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax5a.plot(era5_monthly['date'], era5_monthly['melt_Gt'], '-', 
              color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax5a.plot(cru_monthly['date'], cru_monthly['melt_Gt'], '-', 
              color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    ax5a.set_ylabel('Glacier Melt (Gt/month)', fontsize=13, fontweight='bold')
    ax5a.set_title('Monthly Glacier Melt - DA1 Cluster', 
                   fontsize=14, fontweight='bold')
    ax5a.legend(loc='best', fontsize=10, framealpha=0.95)
    ax5a.grid(True, alpha=0.4, linestyle='--')
    
    # BOTTOM PANEL: Rainfall on Glacier
    ax5b.plot(cr2_monthly['date'], cr2_monthly['rain_Gt'], '-', 
              color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax5b.plot(era5_monthly['date'], era5_monthly['rain_Gt'], '-', 
              color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax5b.plot(cru_monthly['date'], cru_monthly['rain_Gt'], '-', 
              color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    ax5b.set_xlabel('Date', fontsize=13, fontweight='bold')
    ax5b.set_ylabel('Rainfall on Glacier (Gt/month)', fontsize=13, fontweight='bold')
    ax5b.set_title('Monthly Rainfall on Glacier - DA1 Cluster', 
                   fontsize=14, fontweight='bold')
    ax5b.legend(loc='best', fontsize=10, framealpha=0.95)
    ax5b.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_05_Melt_vs_Rain_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_05_Melt_vs_Rain_DA1.png")
else:
    print("  ⚠ Warning: Monthly melt/rain data not available - skipping Plot 5")

# %%
##############################################################################
# PLOT 6: SEASONAL CYCLE (MEAN ANNUAL PATTERN)
##############################################################################
print("\nCreating Plot 6: Mean Seasonal Cycle...")

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    fig6, (ax6a, ax6b) = plt.subplots(1, 2, figsize=(16, 7))
    
    # Calculate mean monthly values across all years
    cr2_seasonal_melt = cr2_monthly.groupby('month')['melt_Gt'].mean()
    era5_seasonal_melt = era5_monthly.groupby('month')['melt_Gt'].mean()
    cru_seasonal_melt = cru_monthly.groupby('month')['melt_Gt'].mean()
    
    cr2_seasonal_rain = cr2_monthly.groupby('month')['rain_Gt'].mean()
    era5_seasonal_rain = era5_monthly.groupby('month')['rain_Gt'].mean()
    cru_seasonal_rain = cru_monthly.groupby('month')['rain_Gt'].mean()
    
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    
    # LEFT PANEL: Mean seasonal melt cycle
    ax6a.plot(range(1, 13), cr2_seasonal_melt, 'o-', 
              color=colors['CR2MET'], linewidth=2.5, markersize=8, 
              label='CR2MET', alpha=0.8)
    ax6a.plot(range(1, 13), era5_seasonal_melt, 's-', 
              color=colors['ERA5'], linewidth=2.5, markersize=8, 
              label='ERA5', alpha=0.8)
    ax6a.plot(range(1, 13), cru_seasonal_melt, '^-', 
              color=colors['CRU'], linewidth=2.5, markersize=8, 
              label='CRU', alpha=0.8)
    
    ax6a.set_xlabel('Month', fontsize=13, fontweight='bold')
    ax6a.set_ylabel('Mean Monthly Melt (Gt)', fontsize=13, fontweight='bold')
    ax6a.set_title('Mean Seasonal Melt Cycle\n(Average 2000-2019)', 
                   fontsize=14, fontweight='bold')
    ax6a.set_xticks(range(1, 13))
    ax6a.set_xticklabels(months, rotation=45)
    ax6a.legend(loc='best', fontsize=10)
    ax6a.grid(True, alpha=0.4, linestyle='--')
    
    # RIGHT PANEL: Mean seasonal rain cycle
    ax6b.plot(range(1, 13), cr2_seasonal_rain, 'o-', 
              color=colors['CR2MET'], linewidth=2.5, markersize=8, 
              label='CR2MET', alpha=0.8)
    ax6b.plot(range(1, 13), era5_seasonal_rain, 's-', 
              color=colors['ERA5'], linewidth=2.5, markersize=8, 
              label='ERA5', alpha=0.8)
    ax6b.plot(range(1, 13), cru_seasonal_rain, '^-', 
              color=colors['CRU'], linewidth=2.5, markersize=8, 
              label='CRU', alpha=0.8)
    
    ax6b.set_xlabel('Month', fontsize=13, fontweight='bold')
    ax6b.set_ylabel('Mean Monthly Rain (Gt)', fontsize=13, fontweight='bold')
    ax6b.set_title('Mean Seasonal Rain Cycle\n(Average 2000-2019)', 
                   fontsize=14, fontweight='bold')
    ax6b.set_xticks(range(1, 13))
    ax6b.set_xticklabels(months, rotation=45)
    ax6b.legend(loc='best', fontsize=10)
    ax6b.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_06_Seasonal_Cycle_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_06_Seasonal_Cycle_DA1.png")
else:
    print("  ⚠ Warning: Monthly data not available - skipping Plot 6")

# %%
##############################################################################
# SUMMARY TABLE: SAVE KEY STATISTICS
##############################################################################
print("\nCreating summary statistics table...")

summary_stats = pd.DataFrame({
    'Dataset': ['CR2MET', 'ERA5', 'CRU'],
    'Mean MB (m/yr)': [cr2_mb_mean, era5_mb_mean, cru_mb_mean],
    'Volume Change (km³)': [
        cr2_totals.iloc[-1]['volume_km3'] - cr2_totals.iloc[0]['volume_km3'],
        era5_totals.iloc[-1]['volume_km3'] - era5_totals.iloc[0]['volume_km3'],
        cru_totals.iloc[-1]['volume_km3'] - cru_totals.iloc[0]['volume_km3']
    ],
    'Area Change (km²)': [
        cr2_totals.iloc[-1]['area_km2'] - cr2_totals.iloc[0]['area_km2'],
        era5_totals.iloc[-1]['area_km2'] - era5_totals.iloc[0]['area_km2'],
        cru_totals.iloc[-1]['area_km2'] - cru_totals.iloc[0]['area_km2']
    ],
    'Area Change (%)': [cr2_area_pct, era5_area_pct, cru_area_pct]
})

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    summary_stats['Total Melt (Gt)'] = [
        cr2_monthly['melt_Gt'].sum(),
        era5_monthly['melt_Gt'].sum(),
        cru_monthly['melt_Gt'].sum()
    ]
    summary_stats['Total Rain (Gt)'] = [
        cr2_monthly['rain_Gt'].sum(),
        era5_monthly['rain_Gt'].sum(),
        cru_monthly['rain_Gt'].sum()
    ]

summary_stats.to_csv(output_dir + 'Timeseries_Summary_Statistics_DA1.csv', index=False)
print("\n  ✓ Saved: Timeseries_Summary_Statistics_DA1.csv")

print("\n" + "="*70)
print("TIMESERIES ANALYSIS COMPLETE!")
print("="*70)
print(f"\nAll plots saved to: {output_dir}")
print("\nPlots created:")
print("  1. Timeseries_01_Mass_Balance_DA1.png - Annual MB timeseries")
print("  2. Timeseries_02_Volume_Evolution_DA1.png - Volume change over time")
print("  3. Timeseries_03_Area_Evolution_DA1.png - Area change over time")
if cr2_monthly is not None:
    print("  4. Timeseries_04_Monthly_Runoff_DA1.png - Monthly runoff (melt + rain)")
    print("  5. Timeseries_05_Melt_vs_Rain_DA1.png - Separate melt and rain")
    print("  6. Timeseries_06_Seasonal_Cycle_DA1.png - Mean seasonal patterns")
print("  Summary table: Timeseries_Summary_Statistics_DA1.csv")
print("="*70)

# Show summary statistics
print("\nSUMMARY STATISTICS:")
print(summary_stats.to_string(index=False))

plt.show()

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
==============================================================================
MULTI-DATASET TIMESERIES COMPARISON - DA1 CLUSTER
==============================================================================
This script creates temporal analysis plots comparing CR2MET, ERA5, and CRU
climate datasets to see how they differ over time (2000-2019).

Author: [Your name]
Date: January 2026
Dataset: DA1 Cluster (Chilean Andes)
==============================================================================
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import seaborn as sns
from datetime import datetime

# Set plotting style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Define output directory
output_dir = '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/'

##############################################################################
# SECTION 1: LOAD GEODETIC OBSERVATIONS FOR REFERENCE
##############################################################################
print("\n" + "="*70)
print("LOADING DATA...")
print("="*70)

# Load geodetic mass balance (GMB) - our "ground truth" observations
# This comes from Hugonnet et al. (2021) satellite observations
gmb_file = output_dir + 'CR2MET/DA1/comparacion_gmb_smb_DA1_.csv'
gmb_data = pd.read_csv(gmb_file, header=None)
gmb_value = float(gmb_data[gmb_data[1] == 'GMB'][0].values[0])
gmb_error = float(gmb_data[gmb_data[1] == 'GMB_error'][0].values[0])

print(f"Geodetic observations (2000-2019): {gmb_value:.1f} ± {gmb_error:.1f} mm/yr")

##############################################################################
# SECTION 2: LOAD ANNUAL MASS BALANCE TIMESERIES
##############################################################################
print("\nLoading annual mass balance timeseries...")

# Load area-weighted mean mass balance for each year
# These are the cluster-wide averages calculated in Script 02
cr2_mb_ts = pd.read_csv(output_dir + 'CR2MET/DA1/mb_promedio.csv')
era5_mb_ts = pd.read_csv(output_dir + 'ERA5/DA1/mb_promedio.csv')
cru_mb_ts = pd.read_csv(output_dir + 'CRU/DA1/mb_promedio.csv')

print(f"  CR2MET: {len(cr2_mb_ts)} years")
print(f"  ERA5:   {len(era5_mb_ts)} years")
print(f"  CRU:    {len(cru_mb_ts)} years")

##############################################################################
# SECTION 3: LOAD COMPILED NETCDF FILES WITH FULL GLACIER EVOLUTION
##############################################################################
print("\nLoading compiled NetCDF outputs (volume, area, length)...")

# These NetCDF files contain annual timeseries of glacier geometry changes
# for all glaciers in the cluster, compiled from OGGM simulations
cr2_nc = xr.open_dataset(output_dir + 'CR2MET/DA1/run_output_2000_2019_hydro_TC_DA1.nc')
era5_nc = xr.open_dataset(output_dir + 'ERA5/DA1/run_output_2000_2019_hydro_ERA5_DA1.nc')
cru_nc = xr.open_dataset(output_dir + 'CRU/DA1/run_output_2000_2019_hydro_CRU_DA1.nc')

print("  Variables available in NetCDF files:")
print(f"    {list(cr2_nc.data_vars)}")

##############################################################################
# SECTION 4: EXTRACT CLUSTER-WIDE TOTALS FOR VOLUME AND AREA
##############################################################################
print("\nCalculating cluster-wide totals...")

def calculate_cluster_totals(nc_dataset):
    """
    Calculate total volume and area across all glaciers in the cluster.
    
    Parameters:
    -----------
    nc_dataset : xarray.Dataset
        OGGM compiled output with variables: volume, area, etc.
    
    Returns:
    --------
    pandas.DataFrame with columns: year, volume_km3, area_km2
    """
    # Sum across all glaciers (axis=0 is the glacier dimension)
    total_volume = nc_dataset['volume'].sum(dim='rgi_id') / 1e9  # Convert m³ to km³
    total_area = nc_dataset['area'].sum(dim='rgi_id') / 1e6     # Convert m² to km²
    
    # Get years from time dimension
    years = nc_dataset['time'].values
    
    # Create DataFrame
    df = pd.DataFrame({
        'year': years,
        'volume_km3': total_volume.values,
        'area_km2': total_area.values
    })
    
    return df

# Calculate totals for each dataset
cr2_totals = calculate_cluster_totals(cr2_nc)
era5_totals = calculate_cluster_totals(era5_nc)
cru_totals = calculate_cluster_totals(cru_nc)

print(f"  Initial volume (2000): CR2MET={cr2_totals.iloc[0]['volume_km3']:.2f} km³")
print(f"  Final volume (2019):   CR2MET={cr2_totals.iloc[-1]['volume_km3']:.2f} km³")
print(f"  Volume loss:           {cr2_totals.iloc[0]['volume_km3'] - cr2_totals.iloc[-1]['volume_km3']:.2f} km³")

##############################################################################
# SECTION 5: EXTRACT MONTHLY HYDROLOGY DATA
##############################################################################
print("\nExtracting monthly hydrology (melt, precipitation, runoff)...")

def extract_monthly_hydrology(nc_dataset):
    """
    Extract monthly hydrological fluxes summed across all glaciers.
    
    Parameters:
    -----------
    nc_dataset : xarray.Dataset
        OGGM compiled output with monthly_* variables
    
    Returns:
    --------
    pandas.DataFrame with monthly timeseries of melt, precip, runoff
    """
    # First, let's see what's actually in the dataset
    print(f"    Available variables: {list(nc_dataset.data_vars)}")
    print(f"    Available dimensions: {list(nc_dataset.dims)}")
    
    # Look for monthly hydrology variables
    # In OGGM outputs, these are often stored in the 'calendar_month_2d' dimension
    # or as separate monthly storage variables
    
    monthly_vars = [v for v in nc_dataset.data_vars if 'month' in v.lower()]
    print(f"    Monthly variables found: {monthly_vars}")
    
    if not monthly_vars:
        print("    Warning: No monthly variables found in dataset")
        return None
    
    # Try to find the actual dimension name for months
    sample_var = monthly_vars[0] if monthly_vars else None
    if sample_var:
        dims = nc_dataset[sample_var].dims
        print(f"    Dimensions of '{sample_var}': {dims}")
    
    # Check if we have the standard OGGM monthly hydrology output
    # These are typically stored with dimensions (rgi_id, time, calendar_month_2d)
    if 'calendar_month_2d' in nc_dataset.dims:
        month_dim = 'calendar_month_2d'
    elif 'month_2d' in nc_dataset.dims:
        month_dim = 'month_2d'
    else:
        print("    Warning: Could not find monthly dimension - skipping monthly analysis")
        return None
    
    # Extract and sum monthly fluxes across all glaciers
    melt = None
    rain = None
    snow = None
    
    # Try different variable name conventions
    for melt_name in ['melt_on_glacier', 'melt_on_glacier_monthly']:
        if melt_name in nc_dataset:
            melt = nc_dataset[melt_name].sum(dim='rgi_id')
            print(f"    Found melt data: {melt_name}")
            break
    
    for rain_name in ['liq_prcp_on_glacier', 'liq_prcp_on_glacier_monthly']:
        if rain_name in nc_dataset:
            rain = nc_dataset[rain_name].sum(dim='rgi_id')
            print(f"    Found rain data: {rain_name}")
            break
    
    for snow_name in ['snowfall_on_glacier', 'snowfall_on_glacier_monthly']:
        if snow_name in nc_dataset:
            snow = nc_dataset[snow_name].sum(dim='rgi_id')
            print(f"    Found snow data: {snow_name}")
            break
    
    if melt is None and rain is None:
        print("    Warning: No melt or rain data found")
        return None
    
    # Get years from time dimension
    years = nc_dataset['time'].values
    
    # Build DataFrame
    monthly_data = []
    for i, year in enumerate(years):
        for month in range(12):
            date = pd.Timestamp(year=int(year), month=month+1, day=15)
            row = {'date': date, 'year': int(year), 'month': month+1}
            
            try:
                if melt is not None:
                    # Use the correct dimension name
                    row['melt_kg'] = float(melt.isel(time=i).isel({month_dim: month}).values)
                if rain is not None:
                    row['rain_kg'] = float(rain.isel(time=i).isel({month_dim: month}).values)
                if snow is not None:
                    row['snow_kg'] = float(snow.isel(time=i).isel({month_dim: month}).values)
            except Exception as e:
                print(f"    Warning: Could not extract month {month+1} of year {year}: {e}")
                continue
            
            monthly_data.append(row)
    
    if not monthly_data:
        print("    Warning: No monthly data extracted")
        return None
    
    df = pd.DataFrame(monthly_data)
    
    # Calculate total runoff (melt + rain)
    if 'melt_kg' in df.columns and 'rain_kg' in df.columns:
        df['runoff_kg'] = df['melt_kg'] + df['rain_kg']
    
    return df

# Extract monthly data for each dataset
cr2_monthly = extract_monthly_hydrology(cr2_nc)
era5_monthly = extract_monthly_hydrology(era5_nc)
cru_monthly = extract_monthly_hydrology(cru_nc)

if cr2_monthly is not None:
    print(f"  Monthly data extracted: {len(cr2_monthly)} months")
    print(f"  Available columns: {list(cr2_monthly.columns)}")

##############################################################################
# SECTION 6: CALCULATE PERIOD MEANS FOR EACH DATASET
##############################################################################
print("\nCalculating period means (2000-2019)...")

# First check what columns are actually in the dataframe
print(f"  CR2MET columns: {list(cr2_mb_ts.columns)}")
print(f"  ERA5 columns: {list(era5_mb_ts.columns)}")

# The column might be named differently - check for common variations
mb_col = None
for possible_name in ['mb_mean', 'mean', 'MB', 'mass_balance', 'mb']:
    if possible_name in cr2_mb_ts.columns:
        mb_col = possible_name
        break

if mb_col is None:
    # If still not found, just use the second column (first is usually 'year')
    mb_col = cr2_mb_ts.columns[1]
    print(f"  Using column: {mb_col}")

# Mass balance period means
cr2_mb_mean = cr2_mb_ts[mb_col].mean()
era5_mb_mean = era5_mb_ts[mb_col].mean()
cru_mb_mean = cru_mb_ts[mb_col].mean()

print(f"  CR2MET mean MB:  {cr2_mb_mean:.3f} m w.e./yr")
print(f"  ERA5 mean MB:    {era5_mb_mean:.3f} m w.e./yr")
print(f"  CRU mean MB:     {cru_mb_mean:.3f} m w.e./yr")

# Volume change rates (km³/yr)
cr2_vol_change = (cr2_totals.iloc[-1]['volume_km3'] - cr2_totals.iloc[0]['volume_km3']) / len(cr2_totals)
era5_vol_change = (era5_totals.iloc[-1]['volume_km3'] - era5_totals.iloc[0]['volume_km3']) / len(era5_totals)
cru_vol_change = (cru_totals.iloc[-1]['volume_km3'] - cru_totals.iloc[0]['volume_km3']) / len(cru_totals)

print(f"  CR2MET volume change:  {cr2_vol_change:.4f} km³/yr")
print(f"  ERA5 volume change:    {era5_vol_change:.4f} km³/yr")
print(f"  CRU volume change:     {cru_vol_change:.4f} km³/yr")

##############################################################################
# PLOT 1: ANNUAL MASS BALANCE TIMESERIES
##############################################################################
print("\nCreating Plot 1: Annual Mass Balance Timeseries...")

fig1, ax1 = plt.subplots(figsize=(14, 8))

# Define colors for consistency
colors = {'CR2MET': '#e74c3c', 'ERA5': '#3498db', 'CRU': '#2ecc71'}

# Get year column name (first column is usually year)
year_col = cr2_mb_ts.columns[0]

# Plot annual mass balance timeseries for each dataset
ax1.plot(cr2_mb_ts[year_col], cr2_mb_ts[mb_col], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax1.plot(era5_mb_ts[year_col], era5_mb_ts[mb_col], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax1.plot(cru_mb_ts[year_col], cru_mb_ts[mb_col], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Add period mean lines for each dataset (horizontal reference lines)
ax1.axhline(y=cr2_mb_mean, color=colors['CR2MET'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'CR2MET mean: {cr2_mb_mean:.3f} m/yr')
ax1.axhline(y=era5_mb_mean, color=colors['ERA5'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'ERA5 mean: {era5_mb_mean:.3f} m/yr')
ax1.axhline(y=cru_mb_mean, color=colors['CRU'], linestyle='--', 
           linewidth=2, alpha=0.5, label=f'CRU mean: {cru_mb_mean:.3f} m/yr')

# Add geodetic observation reference (converted to m/yr)
ax1.axhline(y=gmb_value/1000, color='darkred', linestyle=':', 
           linewidth=3, label=f'Geodetic Obs: {gmb_value/1000:.3f} m/yr', alpha=0.7)
ax1.axhspan((gmb_value - gmb_error)/1000, (gmb_value + gmb_error)/1000, 
           alpha=0.1, color='gray', label='GMB uncertainty')

# Formatting
ax1.set_xlabel('Year', fontsize=14, fontweight='bold')
ax1.set_ylabel('Mass Balance (m w.e./yr)', fontsize=14, fontweight='bold')
ax1.set_title('Annual Mass Balance Timeseries - DA1 Cluster\n' + 
             'Comparison of CR2MET, ERA5, and CRU Climate Forcing',
             fontsize=16, fontweight='bold', pad=20)
ax1.legend(loc='best', fontsize=11, framealpha=0.95)
ax1.grid(True, alpha=0.4, linestyle='--')
ax1.axhline(y=0, color='black', linewidth=1)

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_01_Mass_Balance_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_01_Mass_Balance_DA1.png")

##############################################################################
# PLOT 2: GLACIER VOLUME EVOLUTION
##############################################################################
print("\nCreating Plot 2: Volume Evolution...")

fig2, ax2 = plt.subplots(figsize=(14, 8))

# Plot total glacier volume over time
ax2.plot(cr2_totals['year'], cr2_totals['volume_km3'], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax2.plot(era5_totals['year'], era5_totals['volume_km3'], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax2.plot(cru_totals['year'], cru_totals['volume_km3'], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Add trend lines (linear fit)
from scipy.stats import linregress

for name, totals, color in [('CR2MET', cr2_totals, colors['CR2MET']),
                              ('ERA5', era5_totals, colors['ERA5']),
                              ('CRU', cru_totals, colors['CRU'])]:
    slope, intercept, r_value, p_value, std_err = linregress(totals['year'], totals['volume_km3'])
    trend_line = slope * totals['year'] + intercept
    ax2.plot(totals['year'], trend_line, '--', color=color, linewidth=1.5, 
            alpha=0.5, label=f'{name} trend: {slope:.4f} km³/yr')

# Formatting
ax2.set_xlabel('Year', fontsize=14, fontweight='bold')
ax2.set_ylabel('Total Glacier Volume (km³)', fontsize=14, fontweight='bold')
ax2.set_title('Glacier Volume Evolution - DA1 Cluster\n' + 
             'Total volume change under different climate forcings',
             fontsize=16, fontweight='bold', pad=20)
ax2.legend(loc='best', fontsize=11, framealpha=0.95)
ax2.grid(True, alpha=0.4, linestyle='--')

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_02_Volume_Evolution_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_02_Volume_Evolution_DA1.png")

##############################################################################
# PLOT 3: GLACIER AREA EVOLUTION
##############################################################################
print("\nCreating Plot 3: Area Evolution...")

fig3, ax3 = plt.subplots(figsize=(14, 8))

# Plot total glacier area over time
ax3.plot(cr2_totals['year'], cr2_totals['area_km2'], 'o-', 
         color=colors['CR2MET'], linewidth=2.5, markersize=7, 
         label='CR2MET', alpha=0.8)
ax3.plot(era5_totals['year'], era5_totals['area_km2'], 's-', 
         color=colors['ERA5'], linewidth=2.5, markersize=7, 
         label='ERA5', alpha=0.8)
ax3.plot(cru_totals['year'], cru_totals['area_km2'], '^-', 
         color=colors['CRU'], linewidth=2.5, markersize=7, 
         label='CRU', alpha=0.8)

# Calculate percent change
cr2_area_pct = ((cr2_totals.iloc[-1]['area_km2'] - cr2_totals.iloc[0]['area_km2']) / 
                cr2_totals.iloc[0]['area_km2'] * 100)
era5_area_pct = ((era5_totals.iloc[-1]['area_km2'] - era5_totals.iloc[0]['area_km2']) / 
                 era5_totals.iloc[0]['area_km2'] * 100)
cru_area_pct = ((cru_totals.iloc[-1]['area_km2'] - cru_totals.iloc[0]['area_km2']) / 
                cru_totals.iloc[0]['area_km2'] * 100)

# Formatting
ax3.set_xlabel('Year', fontsize=14, fontweight='bold')
ax3.set_ylabel('Total Glacier Area (km²)', fontsize=14, fontweight='bold')
ax3.set_title('Glacier Area Evolution - DA1 Cluster\n' + 
             f'CR2MET: {cr2_area_pct:.1f}% | ERA5: {era5_area_pct:.1f}% | CRU: {cru_area_pct:.1f}% change',
             fontsize=16, fontweight='bold', pad=20)
ax3.legend(loc='best', fontsize=11, framealpha=0.95)
ax3.grid(True, alpha=0.4, linestyle='--')

plt.tight_layout()
plt.savefig(output_dir + 'Timeseries_03_Area_Evolution_DA1.png', dpi=300, bbox_inches='tight')
print("  ✓ Saved: Timeseries_03_Area_Evolution_DA1.png")

##############################################################################
# PLOT 4: MONTHLY HYDROLOGY - TOTAL RUNOFF
##############################################################################
print("\nCreating Plot 4: Monthly Runoff Timeseries...")

if cr2_monthly is not None and 'runoff_kg' in cr2_monthly.columns:
    fig4, ax4 = plt.subplots(figsize=(16, 8))
    
    # Convert kg to Gt (gigatonnes) for better readability: 1 Gt = 1e12 kg
    cr2_monthly['runoff_Gt'] = cr2_monthly['runoff_kg'] / 1e12
    era5_monthly['runoff_Gt'] = era5_monthly['runoff_kg'] / 1e12
    cru_monthly['runoff_Gt'] = cru_monthly['runoff_kg'] / 1e12
    
    # Plot monthly runoff
    ax4.plot(cr2_monthly['date'], cr2_monthly['runoff_Gt'], '-', 
             color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax4.plot(era5_monthly['date'], era5_monthly['runoff_Gt'], '-', 
             color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax4.plot(cru_monthly['date'], cru_monthly['runoff_Gt'], '-', 
             color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    # Formatting
    ax4.set_xlabel('Date', fontsize=14, fontweight='bold')
    ax4.set_ylabel('Total Runoff (Gt/month)', fontsize=14, fontweight='bold')
    ax4.set_title('Monthly Glacier Runoff - DA1 Cluster\n' + 
                 'Total runoff = glacier melt + rainfall on glacier',
                 fontsize=16, fontweight='bold', pad=20)
    ax4.legend(loc='best', fontsize=11, framealpha=0.95)
    ax4.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_04_Monthly_Runoff_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_04_Monthly_Runoff_DA1.png")
else:
    print("  ⚠ Warning: Monthly runoff data not available - skipping Plot 4")

##############################################################################
# PLOT 5: MONTHLY COMPONENTS - MELT VS RAIN
##############################################################################
print("\nCreating Plot 5: Melt vs Rain Comparison...")

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    fig5, (ax5a, ax5b) = plt.subplots(2, 1, figsize=(16, 12))
    
    # Convert to Gt
    for df in [cr2_monthly, era5_monthly, cru_monthly]:
        df['melt_Gt'] = df['melt_kg'] / 1e12
        df['rain_Gt'] = df['rain_kg'] / 1e12
    
    # TOP PANEL: Glacier Melt
    ax5a.plot(cr2_monthly['date'], cr2_monthly['melt_Gt'], '-', 
              color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax5a.plot(era5_monthly['date'], era5_monthly['melt_Gt'], '-', 
              color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax5a.plot(cru_monthly['date'], cru_monthly['melt_Gt'], '-', 
              color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    ax5a.set_ylabel('Glacier Melt (Gt/month)', fontsize=13, fontweight='bold')
    ax5a.set_title('Monthly Glacier Melt - DA1 Cluster', 
                   fontsize=14, fontweight='bold')
    ax5a.legend(loc='best', fontsize=10, framealpha=0.95)
    ax5a.grid(True, alpha=0.4, linestyle='--')
    
    # BOTTOM PANEL: Rainfall on Glacier
    ax5b.plot(cr2_monthly['date'], cr2_monthly['rain_Gt'], '-', 
              color=colors['CR2MET'], linewidth=1.5, label='CR2MET', alpha=0.7)
    ax5b.plot(era5_monthly['date'], era5_monthly['rain_Gt'], '-', 
              color=colors['ERA5'], linewidth=1.5, label='ERA5', alpha=0.7)
    ax5b.plot(cru_monthly['date'], cru_monthly['rain_Gt'], '-', 
              color=colors['CRU'], linewidth=1.5, label='CRU', alpha=0.7)
    
    ax5b.set_xlabel('Date', fontsize=13, fontweight='bold')
    ax5b.set_ylabel('Rainfall on Glacier (Gt/month)', fontsize=13, fontweight='bold')
    ax5b.set_title('Monthly Rainfall on Glacier - DA1 Cluster', 
                   fontsize=14, fontweight='bold')
    ax5b.legend(loc='best', fontsize=10, framealpha=0.95)
    ax5b.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_05_Melt_vs_Rain_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_05_Melt_vs_Rain_DA1.png")
else:
    print("  ⚠ Warning: Monthly melt/rain data not available - skipping Plot 5")

##############################################################################
# PLOT 6: SEASONAL CYCLE (MEAN ANNUAL PATTERN)
##############################################################################
print("\nCreating Plot 6: Mean Seasonal Cycle...")

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    fig6, (ax6a, ax6b) = plt.subplots(1, 2, figsize=(16, 7))
    
    # Calculate mean monthly values across all years
    cr2_seasonal_melt = cr2_monthly.groupby('month')['melt_Gt'].mean()
    era5_seasonal_melt = era5_monthly.groupby('month')['melt_Gt'].mean()
    cru_seasonal_melt = cru_monthly.groupby('month')['melt_Gt'].mean()
    
    cr2_seasonal_rain = cr2_monthly.groupby('month')['rain_Gt'].mean()
    era5_seasonal_rain = era5_monthly.groupby('month')['rain_Gt'].mean()
    cru_seasonal_rain = cru_monthly.groupby('month')['rain_Gt'].mean()
    
    months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
              'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    
    # LEFT PANEL: Mean seasonal melt cycle
    ax6a.plot(range(1, 13), cr2_seasonal_melt, 'o-', 
              color=colors['CR2MET'], linewidth=2.5, markersize=8, 
              label='CR2MET', alpha=0.8)
    ax6a.plot(range(1, 13), era5_seasonal_melt, 's-', 
              color=colors['ERA5'], linewidth=2.5, markersize=8, 
              label='ERA5', alpha=0.8)
    ax6a.plot(range(1, 13), cru_seasonal_melt, '^-', 
              color=colors['CRU'], linewidth=2.5, markersize=8, 
              label='CRU', alpha=0.8)
    
    ax6a.set_xlabel('Month', fontsize=13, fontweight='bold')
    ax6a.set_ylabel('Mean Monthly Melt (Gt)', fontsize=13, fontweight='bold')
    ax6a.set_title('Mean Seasonal Melt Cycle\n(Average 2000-2019)', 
                   fontsize=14, fontweight='bold')
    ax6a.set_xticks(range(1, 13))
    ax6a.set_xticklabels(months, rotation=45)
    ax6a.legend(loc='best', fontsize=10)
    ax6a.grid(True, alpha=0.4, linestyle='--')
    
    # RIGHT PANEL: Mean seasonal rain cycle
    ax6b.plot(range(1, 13), cr2_seasonal_rain, 'o-', 
              color=colors['CR2MET'], linewidth=2.5, markersize=8, 
              label='CR2MET', alpha=0.8)
    ax6b.plot(range(1, 13), era5_seasonal_rain, 's-', 
              color=colors['ERA5'], linewidth=2.5, markersize=8, 
              label='ERA5', alpha=0.8)
    ax6b.plot(range(1, 13), cru_seasonal_rain, '^-', 
              color=colors['CRU'], linewidth=2.5, markersize=8, 
              label='CRU', alpha=0.8)
    
    ax6b.set_xlabel('Month', fontsize=13, fontweight='bold')
    ax6b.set_ylabel('Mean Monthly Rain (Gt)', fontsize=13, fontweight='bold')
    ax6b.set_title('Mean Seasonal Rain Cycle\n(Average 2000-2019)', 
                   fontsize=14, fontweight='bold')
    ax6b.set_xticks(range(1, 13))
    ax6b.set_xticklabels(months, rotation=45)
    ax6b.legend(loc='best', fontsize=10)
    ax6b.grid(True, alpha=0.4, linestyle='--')
    
    plt.tight_layout()
    plt.savefig(output_dir + 'Timeseries_06_Seasonal_Cycle_DA1.png', dpi=300, bbox_inches='tight')
    print("  ✓ Saved: Timeseries_06_Seasonal_Cycle_DA1.png")
else:
    print("  ⚠ Warning: Monthly data not available - skipping Plot 6")

##############################################################################
# SUMMARY TABLE: SAVE KEY STATISTICS
##############################################################################
print("\nCreating summary statistics table...")

summary_stats = pd.DataFrame({
    'Dataset': ['CR2MET', 'ERA5', 'CRU'],
    'Mean MB (m/yr)': [cr2_mb_mean, era5_mb_mean, cru_mb_mean],
    'Volume Change (km³)': [
        cr2_totals.iloc[-1]['volume_km3'] - cr2_totals.iloc[0]['volume_km3'],
        era5_totals.iloc[-1]['volume_km3'] - era5_totals.iloc[0]['volume_km3'],
        cru_totals.iloc[-1]['volume_km3'] - cru_totals.iloc[0]['volume_km3']
    ],
    'Area Change (km²)': [
        cr2_totals.iloc[-1]['area_km2'] - cr2_totals.iloc[0]['area_km2'],
        era5_totals.iloc[-1]['area_km2'] - era5_totals.iloc[0]['area_km2'],
        cru_totals.iloc[-1]['area_km2'] - cru_totals.iloc[0]['area_km2']
    ],
    'Area Change (%)': [cr2_area_pct, era5_area_pct, cru_area_pct]
})

if cr2_monthly is not None and 'melt_kg' in cr2_monthly.columns:
    summary_stats['Total Melt (Gt)'] = [
        cr2_monthly['melt_Gt'].sum(),
        era5_monthly['melt_Gt'].sum(),
        cru_monthly['melt_Gt'].sum()
    ]
    summary_stats['Total Rain (Gt)'] = [
        cr2_monthly['rain_Gt'].sum(),
        era5_monthly['rain_Gt'].sum(),
        cru_monthly['rain_Gt'].sum()
    ]

summary_stats.to_csv(output_dir + 'Timeseries_Summary_Statistics_DA1.csv', index=False)
print("\n  ✓ Saved: Timeseries_Summary_Statistics_DA1.csv")

print("\n" + "="*70)
print("TIMESERIES ANALYSIS COMPLETE!")
print("="*70)
print(f"\nAll plots saved to: {output_dir}")
print("\nPlots created:")
print("  1. Timeseries_01_Mass_Balance_DA1.png - Annual MB timeseries")
print("  2. Timeseries_02_Volume_Evolution_DA1.png - Volume change over time")
print("  3. Timeseries_03_Area_Evolution_DA1.png - Area change over time")
if cr2_monthly is not None:
    print("  4. Timeseries_04_Monthly_Runoff_DA1.png - Monthly runoff (melt + rain)")
    print("  5. Timeseries_05_Melt_vs_Rain_DA1.png - Separate melt and rain")
    print("  6. Timeseries_06_Seasonal_Cycle_DA1.png - Mean seasonal patterns")
print("  Summary table: Timeseries_Summary_Statistics_DA1.csv")
print("="*70)

# Show summary statistics
print("\nSUMMARY STATISTICS:")
print(summary_stats.to_string(index=False))

plt.show()
# Out:
# ======================================================================
# LOADING DATA...
# ======================================================================
# Geodetic observations (2000-2019): -98.7 ± 152.6 mm/yr
#
# Loading annual mass balance timeseries...
#   CR2MET: 22 years
#   ERA5:   20 years
#   CRU:    20 years
#
# Loading compiled NetCDF outputs (volume, area, length)...
#   Variables available in NetCDF files:
#     ['volume', 'volume_bsl', 'volume_bwl', 'area', 'length', 'calving', 'calving_rate', 'off_area', 'on_area', 'melt_off_glacier', 'melt_on_glacier', 'liq_prcp_off_glacier', 'liq_prcp_on_glacier', 'snowfall_off_glacier', 'snowfall_on_glacier', 'melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly', 'water_level', 'glen_a', 'fs']
#
# Calculating cluster-wide totals...
#   Initial volume (2000): CR2MET=5.60 km³
#   Final volume (2019):   CR2MET=5.34 km³
#   Volume loss:           0.25 km³
#
# Extracting monthly hydrology (melt, precipitation, runoff)...
#     Available variables: ['volume', 'volume_bsl', 'volume_bwl', 'area', 'length', 'calving', 'calving_rate', 'off_area', 'on_area', 'melt_off_glacier', 'melt_on_glacier', 'liq_prcp_off_glacier', 'liq_prcp_on_glacier', 'snowfall_off_glacier', 'snowfall_on_glacier', 'melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly', 'water_level', 'glen_a', 'fs']
#     Available dimensions: ['time', 'rgi_id', 'month_2d']
#     Monthly variables found: ['melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly']
#     Dimensions of 'melt_off_glacier_monthly': ('time', 'month_2d', 'rgi_id')
#     Found melt data: melt_on_glacier
#     Found rain data: liq_prcp_on_glacier
#     Found snow data: snowfall_on_glacier
#     Warning: Could not extract month 1 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2009.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2010.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: No monthly data extracted
#     Available variables: ['volume', 'volume_bsl', 'volume_bwl', 'area', 'length', 'calving', 'calving_rate', 'off_area', 'on_area', 'melt_off_glacier', 'melt_on_glacier', 'liq_prcp_off_glacier', 'liq_prcp_on_glacier', 'snowfall_off_glacier', 'snowfall_on_glacier', 'melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly', 'water_level', 'glen_a', 'fs']
#     Available dimensions: ['time', 'rgi_id', 'month_2d']
#     Monthly variables found: ['melt_off_glacier_monthly', 'melt_on_glacier_monthly', 'liq_prcp_off_glacier_monthly', 'liq_prcp_on_glacier_monthly', 'snowfall_off_glacier_monthly', 'snowfall_on_glacier_monthly']
#     Dimensions of 'melt_off_glacier_monthly': ('time', 'month_2d', 'rgi_id')
#     Found melt data: melt_on_glacier
#     Found rain data: liq_prcp_on_glacier
#     Found snow data: snowfall_on_glacier
#     Warning: Could not extract month 1 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 1999.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2000.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2001.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2002.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2003.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2004.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2005.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2006.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2007.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2008.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
# ...
#     Warning: Could not extract month 5 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2011.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2012.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2013.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2014.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2015.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2016.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2017.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2018.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2019.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 1 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 2 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 3 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 4 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 5 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 6 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 7 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 8 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 9 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 10 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 11 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: Could not extract month 12 of year 2020.0: Dimensions {'month_2d'} do not exist. Expected one or more of ()
#     Warning: No monthly data extracted
#
# Calculating period means (2000-2019)...
#   CR2MET columns: ['itera', 'mb', 'year']
#   ERA5 columns: ['itera', 'mb', 'year']
#   CR2MET mean MB:  -118.356 m w.e./yr
#   ERA5 mean MB:    -95.006 m w.e./yr
#   CRU mean MB:     -96.097 m w.e./yr
#   CR2MET volume change:  -0.0115 km³/yr
#   ERA5 volume change:    -0.0134 km³/yr
#   CRU volume change:     -0.0071 km³/yr
#
# Creating Plot 1: Annual Mass Balance Timeseries...
#   ✓ Saved: Timeseries_01_Mass_Balance_DA1.png
#
# Creating Plot 2: Volume Evolution...
#   ✓ Saved: Timeseries_02_Volume_Evolution_DA1.png
#
# Creating Plot 3: Area Evolution...
#   ✓ Saved: Timeseries_03_Area_Evolution_DA1.png
#
# Creating Plot 4: Monthly Runoff Timeseries...
#   ⚠ Warning: Monthly runoff data not available - skipping Plot 4
#
# Creating Plot 5: Melt vs Rain Comparison...
#   ⚠ Warning: Monthly melt/rain data not available - skipping Plot 5
#
# Creating Plot 6: Mean Seasonal Cycle...
#   ⚠ Warning: Monthly data not available - skipping Plot 6
#
# Creating summary statistics table...
#
#   ✓ Saved: Timeseries_Summary_Statistics_DA1.csv
#
# ======================================================================
# TIMESERIES ANALYSIS COMPLETE!
# ======================================================================
#
# All plots saved to: /Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/
#
# Plots created:
#   1. Timeseries_01_Mass_Balance_DA1.png - Annual MB timeseries
#   2. Timeseries_02_Volume_Evolution_DA1.png - Volume change over time
#   3. Timeseries_03_Area_Evolution_DA1.png - Area change over time
#   Summary table: Timeseries_Summary_Statistics_DA1.csv
# ======================================================================
#
# SUMMARY STATISTICS:
# Dataset  Mean MB (m/yr)  Volume Change (km³)  Area Change (km²)  Area Change (%)
#  CR2MET     -118.356000            -0.253611          -3.687912        -2.506428
#    ERA5      -95.005923            -0.294838          -1.838758        -1.250247
#     CRU      -96.096910            -0.155952          -1.471273        -0.999595

# %% [markdown]
# ## Some quick plots for the regions I've run with CR2met

# %%
#!/usr/bin/env python3
"""
Simple NetCDF-only plotter - extracts mass balance directly from NetCDF
"""

import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from oggm import utils
import warnings

if not hasattr(np, 'warnings'):
    np.warnings = warnings

print("\n" + "="*70)
print("EXTRACTING DATA FROM NETCDF FILES")
print("="*70)

# Clusters and their NetCDF file paths
clusters_to_check = {
    'DA1': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/DA1/run_output_2000_2019_hydro_TC_DA1.nc',
    'DA2': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/DA2/run_output_2000_2019_hydro_TC_DA2.nc',
    'DA3': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/DA3/run_output_2000_2019_hydro_TC_DA3.nc',
    'WA1': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/WA1/run_output_2000_2019_hydro_TC_WA1.nc',
    'WA2': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/WA2/run_output_2000_2019_hydro_TC_WA2.nc',
    'WA3': '/Users/milliespencer/Desktop/CR2_OGGM_Paper/Output/CR2MET/WA3/run_output_2000_2019_hydro_TC_WA3.nc',
}

# Load RGI data
rgi_file = '/Users/milliespencer/Desktop/CR2_OGGM_Paper/files_chile_OGGM_climate_comparison/RGI_BNA_Clusters.csv'
datos_rgi = pd.read_csv(rgi_file)

# Load geodetic data
utils.get_geodetic_mb_dataframe()
geodetic_ref = utils.get_geodetic_mb_dataframe()
geodetic_ref = geodetic_ref[geodetic_ref['period'] == '2000-01-01_2020-01-01']

results = []

for cluster, nc_path in clusters_to_check.items():
    print(f"\n{cluster}:")
    
    try:
        # Open NetCDF
        ds = xr.open_dataset(nc_path)
        print(f"  ✓ Opened NetCDF")
        
        # Get glacier IDs
        glacier_ids = [str(x) for x in ds['rgi_id'].values]
        n_glaciers = len(glacier_ids)
        
        # Calculate mass balance for 2000-2020 (matching calibration period)
        volume_2000 = ds['volume'].sel(time=2000).sum()
        volume_2020 = ds['volume'].sel(time=2020).sum()
        area_2000 = ds['area'].sel(time=2000)
        
        # Volume change in m³, divide by total area and time to get m w.e./yr
        total_area_m2 = area_2000.sum().values
        n_years = 20  # 2000-2020 period (matches calibration)
        
        # SMB in m w.e./yr, then convert to mm/yr
        smb_m_per_yr = (volume_2020 - volume_2000) / total_area_m2 / n_years
        smb_mm_per_yr = float(smb_m_per_yr * 1000)
        
        print(f"  SMB: {smb_mm_per_yr:.1f} mm/yr")
        
        # Get cluster glaciers from RGI
        cluster_glaciers = datos_rgi[datos_rgi['Cluster'] == cluster]['RGIId'].tolist()
        
        # Get geodetic observations
        gmb_data = geodetic_ref[geodetic_ref.index.isin(cluster_glaciers)]
        
        if len(gmb_data) > 0:
            gmb_weighted = np.average(gmb_data['dmdtda'] * 1000, weights=gmb_data['area'])
            gmb_error = np.average(gmb_data['err_dmdtda'] * 1000, weights=gmb_data['area'])
            
            print(f"  GMB: {gmb_weighted:.1f} ± {gmb_error:.1f} mm/yr")
            print(f"  Glaciers: {n_glaciers}")
            
            results.append({
                'cluster': cluster,
                'SMB': smb_mm_per_yr,
                'GMB': gmb_weighted,
                'GMB_error': gmb_error,
                'n_glaciers': n_glaciers,
                'area_km2': float(total_area_m2 / 1e6)
            })
        else:
            print(f"  ⚠ No geodetic data")
        
        ds.close()
        
    except FileNotFoundError:
        print(f"  ✗ File not found")
    except Exception as e:
        print(f"  ✗ Error: {e}")

print(f"\n\nTotal clusters loaded: {len(results)}")

if len(results) == 0:
    print("❌ No data to plot!")
    exit(1)

##############################################################################
# PLOT
##############################################################################

df = pd.DataFrame(results)

fig, ax = plt.subplots(figsize=(14, 8))

n = len(df)
x_pos = np.arange(n)

# SMB - circles
ax.plot(x_pos - 0.1, df['SMB'], 'o', markersize=14, color='#e74c3c', 
       markeredgecolor='black', markeredgewidth=2, label='SMB (CR2MET)', zorder=5)

# GMB - diamonds with error bars
ax.errorbar(x_pos + 0.1, df['GMB'], yerr=df['GMB_error'],
           fmt='D', markersize=14, color='darkred',
           markeredgecolor='black', markeredgewidth=2,
           ecolor='gray', capsize=8, capthick=2,
           linewidth=2, label='GMB (Geodetic)', zorder=10)

ax.axhline(y=0, color='black', linewidth=1, linestyle='--', alpha=0.5)

ax.set_ylabel('Mass Balance (mm w.e./yr)', fontsize=15, fontweight='bold')
ax.set_xlabel('Cluster', fontsize=15, fontweight='bold')
ax.set_title(f'CR2MET Mass Balance - {n} Clusters', fontsize=17, fontweight='bold', pad=20)
ax.set_xticks(x_pos)
ax.set_xticklabels(df['cluster'], fontsize=14, fontweight='bold')
ax.legend(loc='best', fontsize=13)
ax.grid(axis='y', alpha=0.4)

# Labels
for i, row in df.iterrows():
    ax.text(i - 0.1, row['SMB'] + 20, f"{row['SMB']:.1f}", 
           ha='center', va='bottom', fontweight='bold', fontsize=10, color='#e74c3c')
    ax.text(i + 0.1, row['GMB'] - 20, f"{row['GMB']:.1f}", 
           ha='center', va='top', fontsize=10, color='darkred')
    
    bias = row['SMB'] - row['GMB']
    bias_pct = (bias / row['GMB']) * 100
    ax.text(i, min(row['SMB'], row['GMB']) - 60, f'{bias:+.0f}\n({bias_pct:+.0f}%)',
           ha='center', va='top', fontsize=8,
           bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()

output = '/Users/milliespencer/Desktop/CR2_OGGM_Paper/CR2MET_Clusters_Simple.png'
plt.savefig(output, dpi=300, bbox_inches='tight')
print(f"\n✓ Saved: {output}")

print("\n" + "="*70)
print("RESULTS")
print("="*70)
for _, row in df.iterrows():
    bias = row['SMB'] - row['GMB']
    print(f"{row['cluster']}: SMB={row['SMB']:.1f}, GMB={row['GMB']:.1f}, Bias={bias:+.1f}")
print("="*70)

plt.show()
# Out:
# ======================================================================
# EXTRACTING DATA FROM NETCDF FILES
# ======================================================================
#
# DA1:
#   ✓ Opened NetCDF
#   SMB: -93.8 mm/yr
#   GMB: -98.7 ± 152.6 mm/yr
#   Glaciers: 422
#
# DA2:
#   ✓ Opened NetCDF
#   SMB: -287.5 mm/yr
#   GMB: -290.1 ± 146.0 mm/yr
#   Glaciers: 200
#
# DA3:
#   ✓ Opened NetCDF
#   SMB: -449.9 mm/yr
#   GMB: -556.2 ± 157.5 mm/yr
#   Glaciers: 410
#
# WA1:
#   ✓ Opened NetCDF
#   SMB: -430.8 mm/yr
#   GMB: -404.2 ± 159.4 mm/yr
#   Glaciers: 678
#
# WA2:
#   ✓ Opened NetCDF
#   SMB: -660.9 mm/yr
#   GMB: -640.3 ± 201.0 mm/yr
#   Glaciers: 2924
#
# WA3:
#   ✓ Opened NetCDF
#   SMB: -1225.0 mm/yr
#   GMB: -1082.4 ± 144.1 mm/yr
#   Glaciers: 447
#
#
# Total clusters loaded: 6
#
# ✓ Saved: /Users/milliespencer/Desktop/CR2_OGGM_Paper/CR2MET_Clusters_Simple.png
#
# ======================================================================
# RESULTS
# ======================================================================
# DA1: SMB=-93.8, GMB=-98.7, Bias=+4.9
# DA2: SMB=-287.5, GMB=-290.1, Bias=+2.5
# DA3: SMB=-449.9, GMB=-556.2, Bias=+106.2
# WA1: SMB=-430.8, GMB=-404.2, Bias=-26.6
# WA2: SMB=-660.9, GMB=-640.3, Bias=-20.6
# WA3: SMB=-1225.0, GMB=-1082.4, Bias=-142.6
# ======================================================================
